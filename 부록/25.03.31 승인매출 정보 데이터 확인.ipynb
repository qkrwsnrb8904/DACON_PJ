# %% [markdown]
# ## **재무 안정성 분석** (11개)
# ---
# - `납부_보험료이용금액`: 최근 3개월 동안 보험료를 납부한 총 금액.
# - `납부_건강연금이용금액`: 최근 3개월 동안 건강보험 및 연금을 납부한 총 금액.
# - `RP건수_보험_B0M`: 이번 달 보험료 정기결제(RP) 건수.
# - `RP건수_건강_B0M`: 이번 달 건강 관련 정기결제(RP) 건수.
# - `RP후경과월_보험`: 마지막 보험 정기결제 이후 경과한 개월 수.
# - `RP후경과월_건강`: 마지막 건강 정기결제 이후 경과한 개월 수.
# - `증감_RP건수_보험_전월`: 지난달 대비 보험 정기결제 건수 증감량.
# - `증감_RP건수_건강_전월`: 지난달 대비 건강 정기결제 건수 증감량.
# - `정상청구원금_B0M`: 이번 달 정상적으로 청구된 원금 금액.
# - `선입금원금_B0M`: 이번 달 선입금된 원금 금액.
# - `정상입금원금_B0M`: 이번 달 정상적으로 입금된 원금 금액.
#
#
# ## **위험도 평가** (26개)
# ---
# - `최종이용일자_CA`: 현금서비스 최종 이용일자 (마지막으로 현금서비스를 사용한 날짜).
# - `이용건수_CA_B0M`: 이번 달 현금서비스를 몇 번 사용했는지.
# - `이용금액_CA_B0M`: 이번 달 현금서비스로 사용한 총 금액.
# - `이용후경과월_CA`: 현금서비스 거래 후 경과한 개월 수.
# - `이용건수_CA_R12M`: 지난 12개월 동안 현금서비스를 몇 번 사용했는지.
# - `이용금액_CA_R12M`: 지난 12개월 동안 현금서비스로 사용한 총 금액.
# - `최대이용금액_CA_R12M`: 지난 12개월 동안 현금서비스로 사용한 가장 큰 금액.
# - `이용개월수_CA_R12M`: 지난 12개월 동안 현금서비스를 사용한 개월 수.
# - `이용건수_CA_R6M`: 지난 6개월 동안 현금서비스를 몇 번 사용했는지.
# - `이용금액_CA_R6M`: 지난 6개월 동안 현금서비스로 사용한 총 금액.
# - `이용개월수_체크_R6M`: 지난 6개월 동안 체크카드를 사용한 개월 수.
# - `이용건수_CA_R3M`: 지난 3개월 동안 현금서비스를 몇 번 사용했는지.
# - `이용금액_CA_R3M`: 지난 3개월 동안 현금서비스로 사용한 총 금액.
# - `이용개월수_CA_R3M`: 지난 3개월 동안 현금서비스를 사용한 개월 수.
# - `이용횟수_연체_R6M`: 지난 6개월 동안 연체가 발생한 횟수.
# - `이용금액_연체_R6M`: 지난 6개월 동안 연체된 총 금액.
# - `이용횟수_연체_R3M`: 지난 3개월 동안 연체가 발생한 횟수.
# - `이용금액_연체_R3M`: 지난 3개월 동안 연체된 총 금액.
# - `이용횟수_연체_B0M`: 이번 달 연체가 발생한 횟수.
# - `이용금액_연체_B0M`: 이번 달 연체된 총 금액.
# - `신청건수_ATM_CA_B0`: 이번 달 ATM에서 현금서비스를 신청한 건수.
# - `신청건수_ATM_CA_R6M`: 지난 6개월 동안 ATM에서 현금서비스를 신청한 건수.
# - `승인거절건수_B0M`: 이번 달 승인 거절된 총 건수.
# - `승인거절건수_한도초과_B0M`: 이번 달 한도 초과로 승인 거절된 건수.
# - `승인거절건수_R3M`: 지난 3개월 동안 승인 거절된 총 건수.
# - `승인거절건수_한도초과_R3M`: 지난 3개월 동안 한도 초과로 승인 거절된 건수.
#
#
# ## **부채 위험도 평가** (12개)
# ---
# - `이용건수_할부_유이자_B0M`: 이번 달 유이자 할부를 몇 번 사용했는지.
# - `이용금액_할부_유이자_B0M`: 이번 달 유이자 할부로 결제한 총 금액.
# - `이용후경과월_할부_유이자`: 유이자 할부 거래 후 경과한 개월 수.
# - `이용건수_할부_유이자_R12M`: 지난 12개월 동안 유이자 할부를 몇 번 사용했는지.
# - `이용금액_할부_유이자_R12M`: 지난 12개월 동안 유이자 할부로 결제한 총 금액.
# - `최대이용금액_할부_유이자_R12M`: 지난 12개월 동안 유이자 할부로 결제한 가장 큰 금액.
# - `이용개월수_할부_유이자_R12M`: 지난 12개월 동안 유이자 할부를 한 개월 수.
# - `이용건수_할부_유이자_R6M`: 지난 6개월 동안 유이자 할부를 몇 번 사용했는지.
# - `이용금액_할부_유이자_R6M`: 지난 6개월 동안 유이자 할부로 결제한 총 금액.
# - `이용개월수_할부_무이자_R6M`: 지난 6개월 동안 무이자 할부를 한 개월 수.
# - `이용금액_할부_유이자_R3M`: 지난 3개월 동안 유이자 할부로 결제한 총 금액.
# - `이용개월수_할부_유이자_R3M`: 지난 3개월 동안 유이자 할부를 한 개월 수.
#
#
# ## **부채 위험도 분석** (4개)
# ---
# - `할부건수_유이자_3M_R12M`: 지난 12개월 동안 유이자 조건으로 3개월 이하 할부를 몇 번 이용했는지(무이자 및 부분 무이자 제외).
# - `할부건수_유이자_6M_R12M`: 지난 12개월 동안 유이자 조건으로 4~6개월 할부를 몇 번 이용했는지(무이자 및 부분 무이자 제외).
# - `할부건수_유이자_12M_R12M`: 지난 12개월 동안 유이자 조건으로 7~12개월 할부를 몇 번 이용했는지(무이자 및 부분 무이자 제외).
# - `최종카드론_대출이율`: 마지막으로 실행한 장기카드 대출의 연이율.
#
# ## **부채 의존도 분석** (23개)
# ---
# - `최종이용일자_카드론`: 카드론 최종 이용일자 (마지막으로 카드론을 사용한 날짜).
# - `이용건수_카드론_B0M`: 이번 달 카드론을 몇 번 사용했는지.
# - `이용금액_카드론_B0M`: 이번 달 카드론으로 빌린 총 금액.
# - `이용후경과월_카드론`: 카드론 거래 후 경과한 개월 수.
# - `이용건수_카드론_R12M`: 지난 12개월 동안 카드론을 몇 번 사용했는지.
# - `이용금액_카드론_R12M`: 지난 12개월 동안 카드론으로 빌린 총 금액.
# - `최대이용금액_카드론_R12M`: 지난 12개월 동안 카드론으로 빌린 가장 큰 금액.
# - `이용개월수_카드론_R12M`: 지난 12개월 동안 카드론을 사용한 개월 수.
# - `이용건수_카드론_R6M`: 지난 6개월 동안 카드론을 몇 번 사용했는지.
# - `이용금액_카드론_R6M`: 지난 6개월 동안 카드론으로 빌린 총 금액.
# - `이용건수_신용_R3M`: 지난 3개월 동안 일시불, 할부, 현금서비스, 카드론을 합산한 총 이용 건수.
# - `이용건수_카드론_R3M`: 지난 3개월 동안 카드론을 몇 번 사용했는지.
# - `이용금액_카드론_R3M`: 지난 3개월 동안 카드론으로 빌린 총 금액.
# - `이용개월수_카드론_R3M`: 지난 3개월 동안 카드론을 사용한 개월 수.
# - `최초카드론이용경과월`: 최초로 카드론을 이용한 이후 경과한 개월 수.
# - `최종카드론이용경과월`: 마지막으로 카드론을 이용한 이후 경과한 개월 수.
# - `카드론이용건수_누적`: 누적된 카드론 이용 건수.
# - `카드론이용월수_누적`: 누적된 카드론 이용 월 수.
# - `카드론이용금액_누적`: 누적된 카드론 이용 금액.
# - `최종카드론_대출일자`: 마지막으로 실행된 장기카드 대출의 날짜.
# - `최종카드론_대출월수`: 마지막으로 실행된 장기카드 대출의 약정 기간(개월 수).
# - `신청건수_ATM_CL_B0`: 이번 달 ATM에서 카드론을 신청한 건수.
# - `신청건수_ATM_CL_R6M`: 지난 6개월 동안 ATM에서 카드론을 신청한 건수.
#
# ## **부채 규모 분석** (1개)
# ---
# - `최종카드론_대출금액`: 마지막으로 실행한 장기카드 대출의 대출 금액.
#
# ## **생활 안정성 분석** (16개)
# ---
# - `납부_통신비이용금액`: 최근 3개월 동안 통신비(인터넷, 휴대폰 등)로 결제한 총 금액.
# - `납부_관리비이용금액`: 최근 3개월 동안 관리비(아파트 관리비 등)로 결제한 총 금액.
# - `납부_가스전기료이용금액`: 최근 3개월 동안 가스 및 전기 요금을 납부한 총 금액.
# - `_1순위납부업종`: 최근 3개월 동안 가장 많이 납부한 항목의 업종(예: 통신비, 관리비 등).
# - `_1순위납부업종_이용금액`: 최근 3개월 동안 가장 많이 납부한 항목의 총 금액(1순위).
# - `RP건수_통신_B0M`: 이번 달 통신비 정기결제(RP) 건수.
# - `RP건수_아파트_B0M`: 이번 달 아파트 관리비 정기결제(RP) 건수.
# - `RP건수_가스_B0M`: 이번 달 가스 요금 정기결제(RP) 건수.
# - `RP건수_전기_B0M`: 이번 달 전기 요금 정기결제(RP) 건수.
# - `RP후경과월_통신`: 마지막 통신비 정기결제 이후 경과한 개월 수.
# - `RP후경과월_아파트`: 마지막 아파트 관리비 정기결제 이후 경과한 개월 수.
# - `RP후경과월_가스`: 마지막 가스 요금 정기결제 이후 경과한 개월 수.
# - `증감_RP건수_통신_전월`: 지난달 대비 통신비 정기결제 건수 증감량.
# - `증감_RP건수_아파트_전월`: 지난달 대비 아파트 관리비 정기결제 건수 증감량.
# - `증감_RP건수_가스_전월`: 지난달 대비 가스 요금 정기결제 건수 증감량.
# - `증감_RP건수_전기_전월`: 지난달 대비 전기 요금 정기결제 건수 증감량.
#
# ## **소비 패턴 분석** (46개)
# ---
# - `최종이용일자_신판`: 신용카드 최종 이용일자 (마지막으로 신용판매를 사용한 날짜).
# - `이용후경과월_신판`: 신판 거래 후 경과한 개월 수.
# - `이용건수_신판_R12M`: 지난 12개월 동안 일시불+할부 거래를 몇 번 했는지.
# - `이용개월수_신판_R12M`: 지난 12개월 동안 일시불+할부 거래를 한 개월 수.
# - `이용건수_신판_R6M`: 지난 6개월 동안 일시불+할부 거래를 몇 번 했는지.
# - `이용개월수_일시불_R6M`: 지난 6개월 동안 일시불 거래를 한 개월 수.
# - `이용건수_일시불_R3M`: 지난 3개월 동안 일시불 거래를 몇 번 했는지.
# - `이용개월수_신판_R3M`: 지난 3개월 동안 일시불+할부 거래를 한 개월 수.
# - `이용금액_해외`: 최근 3개월 동안 해외에서 결제한 총 금액.
# - `쇼핑_도소매_이용금액`: 최근 3개월 동안 도소매 쇼핑으로 결제한 총 금액.
# - `쇼핑_아울렛_이용금액`: 최근 3개월 동안 아울렛에서 결제한 총 금액.
# - `쇼핑_온라인_이용금액`: 최근 3개월 동안 온라인 쇼핑으로 결제한 총 금액.
# - `_1순위업종`: 최근 3개월 동안 가장 많이 이용한 업종(1순위).
# - `_1순위쇼핑업종`: 최근 3개월 동안 가장 많이 이용한 쇼핑 업종(1순위).
# - `_1순위교통업종`: 최근 3개월 동안 가장 많이 이용한 교통 관련 업종(1순위).
# - `할부건수_3M_R12M`: 지난 12개월 동안 3개월 이하 할부를 몇 번 이용했는지.
# - `할부건수_6M_R12M`: 지난 12개월 동안 4~6개월 할부를 몇 번 이용했는지.
# - `할부건수_12M_R12M`: 지난 12개월 동안 7~12개월 할부를 몇 번 이용했는지.
# - `RP건수_B0M`: 이번 달 정기결제(RP) 건수.
# - `RP후경과월`: 마지막 정기결제 이후 경과한 개월 수.
# - `증감_RP건수_전월`: 지난달 대비 정기결제(RP) 건수 증감량.
# - `이용개월수_온라인_R6M`: 지난 6개월 동안 온라인 거래를 한 개월 수.
# - `이용개월수_오프라인_R6M`: 지난 6개월 동안 오프라인 거래를 한 개월 수.
# - `이용건수_온라인_R6M`: 지난 6개월 동안 온라인 거래를 몇 번 했는지.
# - `이용건수_오프라인_R6M`: 지난 6개월 동안 오프라인 거래를 몇 번 했는지.
# - `이용건수_온라인_R3M`: 지난 3개월 동안 온라인 거래를 몇 번 했는지.
# - `이용건수_오프라인_R3M`: 지난 3개월 동안 오프라인 거래를 몇 번 했는지.
# - `이용건수_온라인_B0M`: 이번 달 온라인 거래를 몇 번 했는지.
# - `이용건수_오프라인_B0M`: 이번 달 오프라인 거래를 몇 번 했는지.
# - `이용개월수_간편결제_R6M`: 지난 6개월 동안 간편결제를 이용한 개월 수.
# - `이용건수_간편결제_R6M`: 지난 6개월 동안 간편결제를 몇 번 이용했는지.
# - `이용건수_간편결제_R3M`: 지난 3개월 동안 간편결제로 몇 번 거래했는지.
# - `이용건수_간편결제_B0M`: 이번 달 간편결제로 몇 번 거래했는지.
# - `이용개월수_선결제_R6M`: 지난 6개월 동안 선결제를 이용한 개월 수.
# - `이용횟수_선결제_R6M`: 지난 6개월 동안 선결제를 몇 번 이용했는지.
# - `이용건수_선결제_R6M`: 지난 6개월 동안 선결제를 몇 번 이용했는지.
# - `이용횟수_선결제_R3M`: 지난 3개월 동안 선결제를 몇 번 이용했는지.
# - `이용건수_선결제_R3M`: 지난 3개월 동안 선결제를 몇 번 이용했는지.
# - `이용횟수_선결제_B0M`: 이번 달 선결제를 몇 번 이용했는지.
# - `이용개월수_전체_R6M`: 지난 6개월 동안 전체 거래를 한 개월 수.
# - `이용개월수_전체_R3M`: 지난 3개월 동안 전체 거래를 한 개월 수.
# - `건수_할부전환_R6M`: 지난 6개월 동안 할부로 전환한 건수.
# - `건수_할부전환_R3M`: 지난 3개월 동안 할부로 전환한 건수.
# - `연속무실적개월수_기본_24M_카드`: 지난 24개월 동안 카드 사용 실적이 없는 연속 개월 수.
# - `연속유실적개월수_기본_24M_카드`: 지난 24개월 동안 카드 사용 실적이 있는 연속 개월 수.
# - `이용금액대`: 최근 3개월 월 평균 이용금액 구간.
#
# ## **소비 규모 분석** (26개)
# ---
# - `이용금액_일시불_B0M`: 이번 달 일시불로 결제한 총 금액.
# - `최대이용금액_일시불_R12M`: 지난 12개월 동안 일시불로 결제한 가장 큰 금액.
# - `_1순위업종_이용금액`: 최근 3개월 동안 가장 많이 이용한 업종에서 결제한 총 금액(1순위).
# - `_1순위쇼핑업종_이용금액`: 최근 3개월 동안 가장 많이 이용한 쇼핑 업종에서 결제한 총 금액(1순위).
# - `_1순위교통업종_이용금액`: 최근 3개월 동안 가장 많이 이용한 교통 관련 업종에서 결제한 총 금액(1순위).
# - `할부금액_3M_R12M`: 지난 12개월 동안 3개월 이하 할부로 결제한 총 금액.
# - `할부금액_6M_R12M`: 지난 12개월 동안 4~6개월 할부로 결제한 총 금액.
# - `할부금액_12M_R12M`: 지난 12개월 동안 7~12개월 할부로 결제한 총 금액.
# - `할부금액_유이자_3M_R12M`: 지난 12개월 동안 유이자 조건으로 3개월 할부로 결제한 총 금액(무이자 및 부분 무이자 제외).
# - `할부금액_유이자_6M_R12M`: 지난 12개월 동안 유이자 조건으로 4~6개월 할부로 결제한 총 금액(무이자 및 부분 무이자 제외).
# - `할부금액_유이자_12M_R12M`: 지난 12개월 동안 유이자 조건으로 7~12개월 할부로 결제한 총 금액(무이자 및 부분 무이자 제외).
# - `RP금액_B0M`: 이번 달 RP(정기결제)로 결제한 총 금액.
# - `이용금액_온라인_R6M`: 지난 6개월 동안 온라인 거래로 결제한 총 금액.
# - `이용금액_오프라인_R6M`: 지난 6개월 동안 오프라인 거래로 결제한 총 금액.
# - `이용금액_온라인_R3M`: 지난 3개월 동안 온라인 거래로 결제한 총 금액.
# - `이용금액_오프라인_R3M`: 지난 3개월 동안 오프라인 거래로 결제한 총 금액.
# - `이용금액_온라인_B0M`: 이번 달 온라인 거래로 결제한 총 금액.
# - `이용금액_오프라인_B0M`: 이번 달 오프라인 거래로 결제한 총 금액.
# - `이용금액_간편결제_R6M`: 지난 6개월 동안 간편결제로 결제한 총 금액.
# - `이용금액_간편결제_R3M`: 지난 3개월 동안 간편결제로 결제한 총 금액.
# - `이용금액_간편결제_B0M`: 이번 달 간편결제로 결제한 총 금액.
# - `이용금액_선결제_R6M`: 지난 6개월 동안 선결제로 결제한 총 금액.
# - `이용금액_선결제_R3M`: 지난 3개월 동안 선결제로 결제한 총 금액.
# - `이용금액_선결제_B0M`: 이번 달 선결제로 결제한 총 금액.
# - `금액_할부전환_R6M`: 지난 6개월 동안 할부로 전환된 총 금액.
# - `금액_할부전환_R3M`: 지난 3개월 동안 할부로 전환된 총 금액.
#
#
# ## **소비 빈도 분석** (1개)
# ---
# 이용건수_신용_B0M	이용건수 일시불+할부+현금서비스+카드론 (당월) (이번 달에 신용 거래를 몇 번 했는지.)
#
# ## **소비 안정성 분석** (16개)
# ---
# - `최종이용일자_일시불`: 일시불 최종 이용일자 (마지막으로 일시불로 결제한 날짜).
# - `이용건수_신판_B0M`: 이번 달 일시불+할부를 몇 번 사용했는지.
# - `이용건수_일시불_B0M`: 이번 달 일시불로 몇 번 결제했는지.
# - `이용후경과월_일시불`: 일시불 거래 후 경과한 개월 수.
# - `이용건수_일시불_R12M`: 지난 12개월 동안 일시불 거래를 몇 번 했는지.
# - `이용금액_일시불_R12M`: 지난 12개월 동안 일시불로 결제한 총 금액.
# - `이용개월수_일시불_R12M`: 지난 12개월 동안 일시불 거래를 한 개월 수.
# - `이용건수_일시불_R6M`: 지난 6개월 동안 일시불로 몇 번 결제했는지.
# - `이용금액_일시불_R6M`: 지난 6개월 동안 일시불로 결제한 총 금액.
# - `이용개월수_할부_R6M`: 지난 6개월 동안 할부 거래를 한 개월 수.
# - `이용건수_할부_R3M`: 지난 3개월 동안 할부로 몇 번 결제했는지.
# - `이용금액_일시불_R3M`: 지난 3개월 동안 일시불로 결제한 총 금액.
# - `이용개월수_일시불_R3M`: 지난 3개월 동안 일시불 거래를 한 개월 수.
# - `쇼핑_마트_이용금액`: 최근 3개월 동안 마트에서 결제한 총 금액.
# - `교통_주유이용금액`: 최근 3개월 동안 주유소에서 결제한 총 금액.
# - `교통_버스지하철이용금액`: 최근 3개월 동안 버스나 지하철로 결제한 총 금액.
#
# ## **고급 소비 패턴 분석** (14개)
# ---
# - `최종이용일자_할부`: 할부 최종 이용일자 (마지막으로 할부로 결제한 날짜, 미이용 시 00010101).
# - `이용건수_할부_B0M`: 이번 달 할부로 몇 번 결제했는지.
# - `이용금액_할부_B0M`: 이번 달 할부로 결제한 총 금액.
# - `이용후경과월_할부`: 할부 거래 후 경과한 개월 수.
# - `이용건수_할부_R12M`: 지난 12개월 동안 할부로 몇 번 결제했는지.
# - `이용금액_할부_R12M`: 지난 12개월 동안 할부로 결제한 총 금액.
# - `최대이용금액_할부_R12M`: 지난 12개월 동안 할부로 결제한 가장 큰 금액.
# - `이용개월수_할부_R12M`: 지난 12개월 동안 할부 거래를 한 개월 수.
# - `이용건수_할부_R6M`: 지난 6개월 동안 할부로 몇 번 결제했는지.
# - `이용금액_할부_R6M`: 지난 6개월 동안 할부로 결제한 총 금액.
# - `이용개월수_할부_유이자_R6M`: 지난 6개월 동안 유이자 할부 거래를 한 개월 수.
# - `이용건수_할부_유이자_R3M`: 지난 3개월 동안 유이자 할부로 몇 번 결제했는지.
# - `이용금액_할부_R3M`: 지난 3개월 동안 할부로 결제한 총 금액.
# - `이용개월수_할부_R3M`: 지난 3개월 동안 할부 거래를 한 개월 수.
#
# ## **고급 소비 분석** (2개)
# ---
# - `쇼핑_백화점_이용금액`: 최근 3개월 동안 백화점에서 결제한 총 금액.
# - `여유_항공이용금액`: 최근 3개월 동안 항공권 구매로 결제한 총 금액.
#
# ## **여가 활동 분석** (7개)
# ---
# - `여유_운동이용금액`: 최근 3개월 동안 운동 관련 시설이나 활동으로 결제한 총 금액.
# - `여유_Pet이용금액`: 최근 3개월 동안 반려동물 관련 서비스나 상품으로 결제한 총 금액.
# - `여유_공연이용금액`: 최근 3개월 동안 공연 관람으로 결제한 총 금액.
# - `여유_숙박이용금액`: 최근 3개월 동안 숙박 시설에서 결제한 총 금액.
# - `여유_여행이용금액`: 최근 3개월 동안 여행 관련 서비스로 결제한 총 금액.
# - `_1순위여유업종`: 최근 3개월 동안 가장 많이 이용한 여유(레저) 관련 업종.
# - `_1순위여유업종_이용금액`: 최근 3개월 동안 가장 많이 이용한 여유(레저) 관련 업종에서 결제한 총 금액.
#
#
# ## **식별 / 기준** (2개)
# ---
# - `기준년월`: 데이터 기준년월 (데이터를 수집한 기준이 되는 연월).
# - `ID`: 고유 ID (고객을 고유하게 식별하는 번호).
#
#
# # 칼럼 전체 데이터 207개

# %% [markdown]
# <br>

# %%
import pandas as pd 

df = pd.read_csv('3_승인매출정보_merged.csv')
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26976\3247029513.py:3: DtypeWarning: Columns (183) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('3_승인매출정보_merged.csv')
#      기준년월            ID  최종이용일자_기본  최종이용일자_신판  최종이용일자_CA  최종이용일자_카드론  \
# 0  201807  TRAIN_000000   20180719   20180713   20180719       10101
# 1  201807  TRAIN_000001   20180719   20180719   20170728    20170327
# 2  201807  TRAIN_000002   20180706   20180706   20180706    20151119
# 3  201807  TRAIN_000003   20180721   20180715   20180721       10101
# 4  201807  TRAIN_000004   20180124   20180124      10101       10101
#
#    최종이용일자_체크  최종이용일자_일시불  최종이용일자_할부  이용건수_신용_B0M  ...  승인거절건수_한도초과_B0M  \
# 0   20180203    20180709   20180713           11  ...                0
# 1      10101    20180719   20171231           13  ...                0
# 2   20141230    20180706   20180627           12  ...                0
# ...
